# %% [markdown]
# ### TPC4: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
# (1) Criar Lista 
def criarLista():
    lista = []  
    tamanho = int(input("Quantos elementos quer adicionar? "))
    i = 0
    while i < tamanho:
        x = int(input(f"Digite o elemento número {i+1} entre 1 e 100: "))
        if x > 100:
            print("O número tem de ser menor que 100.")
        else:
            lista.append(x)
            i += 1
    return lista

# (2) Ler Lista
def lerLista(lista):
    print("Lista:", lista)

# (3) Soma
def soma(lista):
    total = sum(lista)  
    print("Soma dos elementos:", total)
    return total

# (4) Média
def media(lista):
    total = soma(lista)
    mediafinal = total / len(lista)
    print("Média dos elementos:", mediafinal)
    return mediafinal

# (5) Maior
def maior(lista):
    maior = lista[0]  
    for n in lista:
        if n > maior:
            maior = n  
    print("Maior elemento:", maior)
    return maior

# (6) Menor
def menor(lista):
    menor = lista[0]  
    for n in lista:
        if n < menor:
            menor = n  
    print("Menor elemento:", menor)
    return menor

# (7) Crescente
def crescente(lista):
    for i in range(len(lista) - 1):  
        if lista[i] > lista[i + 1]:  
            print("Não")
            return False
    print("Sim")
    return True

# (8) Decrescente
def decrescente(lista):
    for i in range(len(lista) - 1):  
        if lista[i] < lista[i + 1]:  
            print("Não")
            return False
    print("Sim")
    return True

# (9) Procura um elemento
def procura(x, lista):
    if x in lista:
        posicao = lista.index(x)
        print(f"O número {x} foi encontrado no índice {posicao}.")
    else:
        print("-1")
    return

# Menu da aplicação
def menu():
    print(""" 
    (1) Criar lista
    (2) Listar lista
    (3) Soma
    (4) Média
    (5) Maior
    (6) Menor
    (7) Está ordenada por ordem crescente
    (8) Está ordenada por ordem decrescente
    (9) Procurar um elemento
    (0) Sair
    """)

lista = []  # Variável global que armazena a lista
menu()
op = input("Introduza uma das opções: ")

while op != "0":
    if op == "1":
        lista = criarLista()  # Atualiza a lista
    elif op == "2":
        lerLista(lista)
    elif op == "3":
        soma(lista)
    elif op == "4":
        media(lista)
    elif op == "5":
        maior(lista)
    elif op == "6":
        menor(lista)
    elif op == "7":
        crescente(lista)
    elif op == "8":
        decrescente(lista)
    elif op == "9":
        x = int(input("Digite o número que deseja procurar: "))
        procura(x, lista)
    else:
        print("Opção inválida. Tente novamente.")

    menu()
    op = input("Introduza uma das opções: ")

print("THAT'S ALL FOLKS :)")
# Out:
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# Não
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# Sim
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# O número 5 foi encontrado no índice 4.
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# Menor elemento: 1
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# Menor elemento: 1
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# O número 6 não foi encontrado na lista.
#
#     (1) Criar lista
#     (2) Listar lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) Está ordenada por ordem crescente
#     (8) Está ordenada por ordem decrescente
#     (9) Procurar um elemento
#     (0) Sair
#
# THAT'S ALL FOLKS :)
